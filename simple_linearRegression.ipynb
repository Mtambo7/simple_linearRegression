# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('dataset/02-profits_and_populations.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of     population    profit
# 0       6.1101  17.59200
# 1       5.5277   9.13020
# 2       8.5186  13.66200
# 3       7.0032  11.85400
# 4       5.8598   6.82330
# ..         ...       ...
# 92      5.8707   7.20290
# 93      5.3054   1.98690
# 94      8.2934   0.14454
# 95     13.3940   9.05510
# 96      5.4369   0.61705
#
# [97 rows x 2 columns]>

# %%
df.shape
# Out:
# (97, 2)

# %%
df.head()
# Out:
#    population   profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
df.describe()
# Out:
#        population     profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
df.plot(x= 'population' , y= 'profit')
plt.title('POPULATION VS PROFIT')
plt.xticks(np.arange(min(df['population']), max(df['population'])+1, 1.0))
plt.xlabel('population')
plt.ylabel('profit')
plt.show()

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, 1].values
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.25, random_state = 42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
ypred = model.predict(x_test)

# %%
print(f'b = {model.intercept_}')
print(f'w = {model.coef_}')
# Out:
# b = -4.746244090820274
# w = [1.29086657]

# %%
all_y_pred = model.predict(x)
plt.figure(figsize=(12,6))
plt.plot(x, all_y_pred)
plt.plot(x, y, 'ro')
plt.title('ACTUAL VS PREDICTED')
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel('population')
plt.ylabel('profit')
plt.show()
# Out:
# C:\Users\MICHAEL MTAMBO\AppData\Local\Temp\ipykernel_10900\640574667.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.xticks(np.arange(min(x), max(x)+1, 1))
